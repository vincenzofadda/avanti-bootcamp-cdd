# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/atlantico-academy/datasets/main/titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.to_csv('../data/raw/titanic.csv', index=False)

# %%
print(df['pclass'].unique())
# Out:
# [3 1 2]

# %%
dicionario = pd.DataFrame([
    {
        'variavel': 'survived',
        'descricao': 'Passageiro sobreviveu (1) ou não (0)',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, {
        'variavel': 'pclass',
        'descricao': 'Classe do passageiro (1, 2, 3)',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal'
    }, {
        'variavel': 'sex',
        'descricao': 'Sexo do passageiro',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, {
        'variavel': 'age',
        'descricao': 'Idade do passageiro',
        'tipo': 'quantitativa',
        'subtipo': 'continua'
    }, {
        'variavel': 'sibsp',
        'descricao': 'Número de irmãos/conjuges a bordo',
        'tipo': 'quantitativa',
        'subtipo': 'discreta'
    }, {
        'variavel': 'parch',
        'descricao': 'Número de pais/filhos a bordo',
        'tipo': 'quantitativa',
        'subtipo': 'discreta'
    }, {
        'variavel': 'fare',
        'descricao': 'Tarifa paga pelo passageiro',
        'tipo': 'quantitativa',
        'subtipo': 'continua'
    }, {
        'variavel': 'embarked',
        'descricao': 'Porto de embarque do passageiro (C = Cherbourg; Q = Queenstown; S = Southampton)',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, {
        'variavel': 'class',
        'descricao': 'Classe do bilhete do passageiro (First, Second, Third)',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal'
    }, {
        'variavel': 'who',
        'descricao': 'Categoria do passageiro (man, woman, child)',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, {
        'variavel': 'adult_male',
        'descricao': 'Homem adulto (True) ou não (False)',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, {
        'variavel': 'deck',
        'descricao': 'Deck da cabine do passageiro',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, {
        'variavel': 'embark_town',
        'descricao': 'Cidade de embarque (Cherbourg; Queenstown; Southampton)',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, {
        'variavel': 'alive',
        'descricao': 'Indica se o passageiro está vivo(yes) ou não(no)',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, {
        'variavel': 'alone',
        'descricao': 'Indica se o passageiro estava sozinho no navio',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }, 
])

dicionario.to_csv('../data/external/dictionary.csv', index=False)
dicionario
# Out:
#        variavel                                          descricao  \
# 0      survived               Passageiro sobreviveu (1) ou não (0)
# 1        pclass                     Classe do passageiro (1, 2, 3)
# 2           sex                                 Sexo do passageiro
# 3           age                                Idade do passageiro
# 4         sibsp                  Número de irmãos/conjuges a bordo
# 5         parch                      Número de pais/filhos a bordo
# 6          fare                        Tarifa paga pelo passageiro
# 7      embarked  Porto de embarque do passageiro (C = Cherbourg...
# 8         class  Classe do bilhete do passageiro (First, Second...
# 9           who        Categoria do passageiro (man, woman, child)
# 10   adult_male                 Homem adulto (True) ou não (False)
# 11         deck                       Deck da cabine do passageiro
# 12  embark_town  Cidade de embarque (Cherbourg; Queenstown; Sou...
# ...
